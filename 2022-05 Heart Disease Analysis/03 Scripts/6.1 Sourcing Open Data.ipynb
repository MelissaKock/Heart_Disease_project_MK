# %% [markdown]
# # Importing

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import os

# %%
# Importing Data

path = r'C:\Users\mkock\Desktop\Data Analytics\Data Immersion\Achievement 6\2022-05 Heart Disease Analysis'

df_heart = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Heart_2020.csv'))

# %% [markdown]
# # Data Wrangling

# %%
# Checking data shape

df_heart.shape
# Out:
# (319795, 18)

# %%
# Checking data types

df_heart.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
# Checking all columns

pd.options.display.max_columns = None
df_heart.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# No need to change any data types
# No need to change any column names -  all understandable
# No need to drop any columns - might use in analysis to focus on specific variables

# %% [markdown]
# # Data Cleaning Checks

# %%
# Finding duplicate values

df_heart[df_heart.duplicated()]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2182             No  19.85      No              No     No             0.0
# 3182             No  28.19      No              No     No             0.0
# 3397             No  26.54      No              No     No             0.0
# 3650             No  32.89     Yes              No     No             2.0
# 4061             No  25.84      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319671           No  25.06      No              No     No             0.0
# 319689           No  27.44      No              No     No             0.0
# 319726           No  30.41      No              No     No             0.0
# 319751           No  34.96      No              No     No             0.0
# 319776           No  27.98      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
# Dropping Duplicates

df_heart_1 = df_heart.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
df_heart_1.shape
# Out:
# (301717, 18)

# %%
# Checking mixed data types

for col in df_heart_1.columns.tolist():
  weird = (df_heart_1[[col]].applymap(type) != df_heart_1[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_heart_1[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed datatypes

# %%
# Checking for missing values

df_heart_1.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# No Missing values

# %% [markdown]
# # Basic Descriptive Analysis

# %%
# Conducting descriptive analysis

df_heart_1.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  301717.000000   301717.000000  301717.000000  301717.000000
# mean       28.441970        3.572298       4.121475       7.084559
# std         6.468134        8.140656       8.128288       1.467122
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.410000        0.000000       0.000000       7.000000
# 75%        31.650000        2.000000       4.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %% [markdown]
# Manual Checks:
#
# Count - everything is the same
# Mean - no odd values
# min/max - no odd values

# %% [markdown]
# # Exporting

# %%
# Exporting data to csv

df_heart_1.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'heart_2020_clean.csv'))
